# %%
import pandas as pd

# %%
# upload dataset 
# drop columns as in code.ipynb 
# encoding like code.ipynb
# do train test split first 
# take the train part and do all preprocessing and save models 
# -> use min max scaler 
# -> add K means label find using silhouette

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    s_no                   song_name  song_duration_ms  acousticness  \
# 0     0  Boulevard of Broken Dreams            262333      0.005520
# 1     1                  In The End            216933      0.010300
# 2     2           Seven Nation Army            231733      0.008170
# 3     3                  By The Way            216933      0.026400
# 4     4           How You Remind Me            223826      0.000954
#
#    danceability  energy  instrumentalness  key  liveness  loudness  \
# 0         0.496   0.682          0.000029    8    0.0589    -4.095
# 1         0.542   0.853          0.000000    3    0.1080    -6.407
# 2         0.737   0.463          0.447000    0    0.2550    -7.828
# 3         0.451   0.970          0.003550    0    0.1020    -4.938
# 4         0.447   0.766          0.000000   10    0.1130    -5.065
#
#    audio_mode  speechiness    tempo  time_signature  audio_valence  \
# 0           1       0.0294  167.060               4          0.474
# 1           0       0.0498  105.256               4          0.370
# 2           1       0.0792  123.881               4          0.324
# 3           1       0.1070  122.444               4          0.198
# 4           1       0.0313  172.011               4          0.574
#
#             label
# 0         Popular
# 1  Mildly Popular
# 2         Popular
# 3         Popular
# 4  Potential Flop

# %%
song_name = df['song_name']

# %%
df = df.drop('s_no' , axis = 1)
df= df.drop('song_name' , axis = 1)

# %%
df.head()
# Out:
#    song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0            262333      0.005520         0.496   0.682          0.000029
# 1            216933      0.010300         0.542   0.853          0.000000
# 2            231733      0.008170         0.737   0.463          0.447000
# 3            216933      0.026400         0.451   0.970          0.003550
# 4            223826      0.000954         0.447   0.766          0.000000
#
#    key  liveness  loudness  audio_mode  speechiness    tempo  time_signature  \
# 0    8    0.0589    -4.095           1       0.0294  167.060               4
# 1    3    0.1080    -6.407           0       0.0498  105.256               4
# 2    0    0.2550    -7.828           1       0.0792  123.881               4
# 3    0    0.1020    -4.938           1       0.1070  122.444               4
# 4   10    0.1130    -5.065           1       0.0313  172.011               4
#
#    audio_valence           label
# 0          0.474         Popular
# 1          0.370  Mildly Popular
# 2          0.324         Popular
# 3          0.198         Popular
# 4          0.574  Potential Flop

# %%
# label encoder

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['label'] = le.fit_transform(df['label'])

df.head()
# Out:
#    song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0            262333      0.005520         0.496   0.682          0.000029
# 1            216933      0.010300         0.542   0.853          0.000000
# 2            231733      0.008170         0.737   0.463          0.447000
# 3            216933      0.026400         0.451   0.970          0.003550
# 4            223826      0.000954         0.447   0.766          0.000000
#
#    key  liveness  loudness  audio_mode  speechiness    tempo  time_signature  \
# 0    8    0.0589    -4.095           1       0.0294  167.060               4
# 1    3    0.1080    -6.407           0       0.0498  105.256               4
# 2    0    0.2550    -7.828           1       0.0792  123.881               4
# 3    0    0.1020    -4.938           1       0.1070  122.444               4
# 4   10    0.1130    -5.065           1       0.0313  172.011               4
#
#    audio_valence  label
# 0          0.474      1
# 1          0.370      0
# 2          0.324      1
# 3          0.198      1
# 4          0.574      2

# %%
# train test split 


from sklearn.model_selection import train_test_split


x_train , x_test , y_train , y_test = train_test_split(df.drop('label' , axis = 1) , df['label'] , test_size = 0.1 , random_state = 37)

# %%
x_train.head()
# Out:
#        song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 10960            152984       0.94700         0.594   0.304          0.198000
# 12925            240712       0.00348         0.429   0.996          0.000108
# 10101            271306       0.00073         0.477   0.882          0.210000
# 12423            225539       0.23800         0.600   0.671          0.000000
# 17343            236866       0.20000         0.725   0.974          0.000014
#
#        key  liveness  loudness  audio_mode  speechiness    tempo  \
# 10960    9    0.0933   -15.353           0       0.0290   79.994
# 12925    1    0.3240    -4.338           0       0.1340  158.337
# 10101    0    0.4400    -4.506           0       0.0594  174.015
# 12423    0    0.1640    -4.875           1       0.0893  129.782
# 17343    6    0.1590    -5.323           1       0.0526  127.054
#
#        time_signature  audio_valence
# 10960               4          0.130
# 12925               4          0.185
# 10101               4          0.343
# 12423               4          0.250
# 17343               4          0.727

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
# min max scaler 

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)

# %%
columns = df.columns [:-1]

x_train = pd.DataFrame(x_train , columns= columns)
y_train = pd.DataFrame(y_train)

x_train.head()
# Out:
#    song_duration_ms  acousticness  danceability    energy  instrumentalness  \
# 0          0.078879      0.950803      0.601824  0.303558          0.198596
# 1          0.127962      0.003493      0.434650  0.996994          0.000108
# 2          0.145079      0.000732      0.483283  0.882757          0.210632
# 3          0.119473      0.238955      0.607903  0.671320          0.000000
# 4          0.125810      0.200802      0.734549  0.974948          0.000014
#
#         key  liveness  loudness  audio_mode  speechiness     tempo  \
# 0  0.818182  0.084504  0.580254         0.0     0.030818  0.330120
# 1  0.090909  0.321095  0.853220         0.0     0.142402  0.653426
# 2  0.000000  0.440057  0.849057         0.0     0.063124  0.718127
# 3  0.000000  0.157010  0.839913         1.0     0.094899  0.535585
# 4  0.545455  0.151882  0.828811         1.0     0.055898  0.524328
#
#    time_signature  audio_valence
# 0             0.8       0.132114
# 1             0.8       0.188008
# 2             0.8       0.348577
# 3             0.8       0.254065
# 4             0.8       0.738821

# %%
y_train
# Out:
#        label
# 10960      2
# 12925      2
# 10101      2
# 12423      0
# 17343      2
# ...      ...
# 11898      0
# 4118       0
# 988        0
# 9036       1
# 1935       1
#
# [16951 rows x 1 columns]

# %%
y_train = pd.DataFrame(y_train , columns= ['label'])

# %%
x_train.head()
# Out:
#    song_duration_ms  acousticness  danceability    energy  instrumentalness  \
# 0          0.078879      0.950803      0.601824  0.303558          0.198596
# 1          0.127962      0.003493      0.434650  0.996994          0.000108
# 2          0.145079      0.000732      0.483283  0.882757          0.210632
# 3          0.119473      0.238955      0.607903  0.671320          0.000000
# 4          0.125810      0.200802      0.734549  0.974948          0.000014
#
#         key  liveness  loudness  audio_mode  speechiness     tempo  \
# 0  0.818182  0.084504  0.580254         0.0     0.030818  0.330120
# 1  0.090909  0.321095  0.853220         0.0     0.142402  0.653426
# 2  0.000000  0.440057  0.849057         0.0     0.063124  0.718127
# 3  0.000000  0.157010  0.839913         1.0     0.094899  0.535585
# 4  0.545455  0.151882  0.828811         1.0     0.055898  0.524328
#
#    time_signature  audio_valence
# 0             0.8       0.132114
# 1             0.8       0.188008
# 2             0.8       0.348577
# 3             0.8       0.254065
# 4             0.8       0.738821

# %%
from sklearn.neighbors import LocalOutlierFactor


lof = LocalOutlierFactor(n_neighbors=150 , contamination= 0.01)


outlier_pred_train = lof.fit_predict(x_train)


non_outlier_indices_train = outlier_pred_train != -1

x_train = x_train[non_outlier_indices_train]
y_train = y_train[non_outlier_indices_train]

# %%
#  value counts 

y_train['label'].value_counts()
# Out:
# 2    8647
# 0    4151
# 1    2313
# 3    1670
# Name: label, dtype: int64

# %%
# plot silhouette and elbow graphs , then add cluster labels as preprocessing 

from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score

elbow_score = []
silhouette = []

k_max = 2

silhouette_max = 0 

for k in range(2, 40):

    kmeans = KMeans(n_clusters=k)

    kmeans.fit(x_train)

    elbow_score.append(kmeans.inertia_)

    silhouette.append(silhouette_score(x_train, kmeans.labels_))

    if silhouette[-1] > silhouette_max:
        silhouette_max = silhouette[-1]
        k_max = k

print(max(silhouette))

# %%
# print(k_max)

# %%
# plot graph 

import matplotlib.pyplot as plt

plt.plot(range(2, 40), elbow_score)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.grid(True)
plt.show()

plt.plot(range(2, 40), silhouette)
plt.title('Silhouette Graph')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.axvline(x=k_max, color='red', linestyle='--')
plt.grid(True)
plt.show()

# %%
# # adding k means as label 

# kmeans = KMeans(n_clusters=k_max)

# kmeans.fit(x_train)

# x_train['cluster_label'] = kmeans.labels_

# x_train.head()

# %%
# # adding to test 

# x_test = pd.DataFrame(x_test , columns= columns)

# kmeans.predict(x_test) 

# pred =  kmeans.predict(x_test)

# x_test['cluster_label'] = pred

# x_test.head()

# %%
# extracting new_data.pkl as a dataframe 

sentimental_analysis = pd.read_pickle('new_data.pkl')

sentimental_analysis_label = sentimental_analysis['Sentiments']

df = pd.concat([df,sentimental_analysis_label],axis=1)

df.head()
# Out:
#    song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0            262333      0.005520         0.496   0.682          0.000029
# 1            216933      0.010300         0.542   0.853          0.000000
# 2            231733      0.008170         0.737   0.463          0.447000
# 3            216933      0.026400         0.451   0.970          0.003550
# 4            223826      0.000954         0.447   0.766          0.000000
#
#    key  liveness  loudness  audio_mode  speechiness    tempo  time_signature  \
# 0    8    0.0589    -4.095           1       0.0294  167.060               4
# 1    3    0.1080    -6.407           0       0.0498  105.256               4
# 2    0    0.2550    -7.828           1       0.0792  123.881               4
# 3    0    0.1020    -4.938           1       0.1070  122.444               4
# 4   10    0.1130    -5.065           1       0.0313  172.011               4
#
#    audio_valence  label  Sentiments
# 0          0.474      1          -1
# 1          0.370      0           0
# 2          0.324      1           0
# 3          0.198      1           0
# 4          0.574      2           0

# %%
# 1. KNN 

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors= 1)

knn.fit(x_train , y_train)

knn.score(x_test , y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 0.6427813163481954

# %%
# random forest 

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators= 1000 , n_jobs=-1)

rf.fit(x_train , y_train)

rf.score(x_test , y_test)
# Out:
# /var/folders/rs/jtf0cy911mdgn5npx3104c200000gn/T/ipykernel_24434/1088939630.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train , y_train)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.7685774946921444

# %%
# decition tree 

from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(x_train , y_train)

dt.score(x_test , y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.6199575371549894

# %%
# naive byes 

from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(x_train , y_train)

nb.score(x_test , y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# 0.35668789808917195

# %%
# logistic regression 

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(x_train , y_train)

lr.score(x_test , y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0.5291932059447984

# %%
# SVM linear 

from sklearn.svm import LinearSVC

svc = LinearSVC()

svc.fit(x_train , y_train)

svc.score(x_test , y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearSVC was fitted with feature names
#   warnings.warn(
# 0.5302547770700637

# %%
# # SVM rbf 

# from sklearn.svm import SVC

# svc_rbf = SVC(gamma= 0.01 , C = 100 , kernel='rbf')

# svc_rbf.fit(x_train , y_train)

# svc_rbf.score(x_test , y_test)

# %%
from sklearn.ensemble import VotingClassifier

rf_feature_bagging = RandomForestClassifier(n_estimators=500, max_features=0.9, random_state=42)
rf_bootstrapping = RandomForestClassifier(n_estimators=500, bootstrap=True, random_state=42)
rf_no_bootstrapping = RandomForestClassifier(n_estimators=500, bootstrap=False, random_state=42)

ensemble = VotingClassifier(
    
    estimators=[
        ('rf_feat_bag', rf_feature_bagging),
        ('rf_boot', rf_bootstrapping),
        ('rf_no_boot', rf_no_bootstrapping),
    ],

    voting='soft'

)

ensemble.fit(x_train, y_train)

ensemble.score(x_test, y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.7669851380042463

# %%
# MLP 

from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(100, 100, 100), max_iter=500, alpha=0.0001,
                    solver='sgd', verbose=10,  random_state=21,tol=0.000000001)

mlp.fit(x_train , y_train)

mlp.score(x_test , y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1118: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 1.29971151
# Iteration 2, loss = 1.19589575
# Iteration 3, loss = 1.18770836
# Iteration 4, loss = 1.18596765
# Iteration 5, loss = 1.18482341
# Iteration 6, loss = 1.18380505
# Iteration 7, loss = 1.18289681
# Iteration 8, loss = 1.18200301
# Iteration 9, loss = 1.18113423
# Iteration 10, loss = 1.18022138
# Iteration 11, loss = 1.17939212
# Iteration 12, loss = 1.17850482
# Iteration 13, loss = 1.17773011
# Iteration 14, loss = 1.17682125
# Iteration 15, loss = 1.17597702
# Iteration 16, loss = 1.17508504
# Iteration 17, loss = 1.17422137
# Iteration 18, loss = 1.17330328
# Iteration 19, loss = 1.17236459
# Iteration 20, loss = 1.17140262
# Iteration 21, loss = 1.17045561
# Iteration 22, loss = 1.16942739
# Iteration 23, loss = 1.16846362
# Iteration 24, loss = 1.16747574
# Iteration 25, loss = 1.16655874
# Iteration 26, loss = 1.16569492
# Iteration 27, loss = 1.16482543
# Iteration 28, loss = 1.16390808
# Iteration 29, loss = 1.16313028
# Iteration 30, loss = 1.16234152
# Iteration 31, loss = 1.16161756
# Iteration 32, loss = 1.16075980
# Iteration 33, loss = 1.16016342
# Iteration 34, loss = 1.15940544
# Iteration 35, loss = 1.15875976
# Iteration 36, loss = 1.15806443
# Iteration 37, loss = 1.15745003
# Iteration 38, loss = 1.15682013
# Iteration 39, loss = 1.15622296
# Iteration 40, loss = 1.15559330
# Iteration 41, loss = 1.15508649
# Iteration 42, loss = 1.15437203
# Iteration 43, loss = 1.15392957
# Iteration 44, loss = 1.15351731
# Iteration 45, loss = 1.15298063
# Iteration 46, loss = 1.15258440
# Iteration 47, loss = 1.15202454
# Iteration 48, loss = 1.15157366
# Iteration 49, loss = 1.15110975
# Iteration 50, loss = 1.15070054
# Iteration 51, loss = 1.15032036
# Iteration 52, loss = 1.14990410
# Iteration 53, loss = 1.14957451
# Iteration 54, loss = 1.14920509
# Iteration 55, loss = 1.14885898
# Iteration 56, loss = 1.14853577
# Iteration 57, loss = 1.14808596
